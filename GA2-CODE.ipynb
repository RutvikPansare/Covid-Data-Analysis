# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
mob = pd.read_csv('applemobilitytrends-2021-06-18.csv')
mob.interpolate(method ='linear', limit_direction ='forward')
mob1 = mob[mob.columns[16:]]
mob1.iloc[147]
# Out:
# C:\Users\Rutvik\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 2020-01-23    103.29
# 2020-01-24    113.06
# 2020-01-25    101.88
# 2020-01-26     81.35
# 2020-01-27     97.56
#                ...
# 2021-06-14     87.58
# 2021-06-15     91.74
# 2021-06-16     93.21
# 2021-06-17     97.16
# 2021-06-18    108.43
# Name: 147, Length: 513, dtype: float64

# %%
mob1
# Out:
#       2020-01-23  2020-01-24  2020-01-25  2020-01-26  2020-01-27  2020-01-28  \
# 0          92.94      102.13      102.38      101.41       94.62       89.12
# 1          94.24       93.73       97.06       77.27       83.37       82.73
# 2          99.42      113.34      118.23       91.31       93.37       91.12
# 3         102.56      104.88       98.83       73.64       94.27       93.86
# 4         115.65      109.66       88.59       85.18       95.91       99.40
# ...          ...         ...         ...         ...         ...         ...
# 4686       96.96      133.65      145.36       91.16      106.80      107.51
# 4687      109.15      149.66      120.05       92.82       94.99       99.93
# 4688      109.50      122.58      120.03       91.19      101.50      101.20
# 4689      109.54      132.21      125.12       94.11      103.45      108.04
# 4690      111.67      122.06      138.54       86.44      104.03      104.12
#
# ...

# %%
USA1 = mob1.iloc[147]

columns = mob.columns[16:]
print(len(columns))
# Out:
# 513

# %%
plt.plot(columns,USA1)

# %%
cases = pd.read_excel('owid-covid-data.xlsx')
cases = cases.iloc[91610:92123]
cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 91610 to 92122
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               513 non-null    object
#  1   continent                              513 non-null    object
#  2   location                               513 non-null    object
#  3   date                                   513 non-null    object
#  4   total_cases                            513 non-null    float64
#  5   new_cases                              512 non-null    float64
#  6   new_cases_smoothed                     507 non-null    float64
#  7   total_deaths                           475 non-null    float64
#  8   new_deaths                             475 non-null    float64
#  9   new_deaths_smoothed                    507 non-null    float64
# ...

# %%
plt.plot(cases['date'],cases['total_cases'])

# %%
plt.figure(figsize=(19,5))
plt.subplot(1, 2, 1)
plt.plot(columns,USA1)
plt.xlabel('2020-01-23 to 2021-06-18')
plt.ylabel("Range")
plt.title("Mobility Of People")
plt.subplot(1, 2, 2)
plt.plot(cases['date'],cases['total_vaccinations'])
plt.xlabel('2020-01-23 to 2021-06-18')
plt.ylabel("Number Of People")
plt.title("Number of total vaccinations")
# Out:
# Text(0.5, 1.0, 'Number of total vaccinations')

# %%
plt.figure(figsize=(19,5))
plt.subplot(1, 2, 1)
plt.plot(cases['date'],cases['total_cases'])
plt.subplot(1, 2, 2)
plt.plot(cases['date'],cases['total_vaccinations'])

# %%
plt.figure(figsize=(19,5))
plt.subplot(1, 2, 1)
plt.plot(cases['date'],cases['new_cases'])
plt.subplot(1, 2, 2)
plt.plot(cases['date'],cases['people_vaccinated'])
